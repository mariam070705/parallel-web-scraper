# %%
import requests
print(requests.get("https://example.com").status_code)
# Out:
# 200

# %%
import requests
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor

urls = [
    "https://example.com",
    "https://google.com",
    "https://github.com",
    "https://wikipedia.org"
]

def scrape_title(url):
    try:
        response = requests.get(url, timeout=5)
        soup = BeautifulSoup(response.text, 'html.parser')
        return f"{url} -> {soup.title.string.strip()}"
    except:
        return f"{url} -> Error"

with ThreadPoolExecutor(max_workers=4) as executor:
    results = list(executor.map(scrape_title, urls))

for r in results:
    print(r)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_9724\2313662003.py:15: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(response.text, 'html.parser')
# https://example.com -> Example Domain
# https://google.com -> Google
# https://github.com -> GitHub · Change is constant. GitHub keeps you ahead. · GitHub
# https://wikipedia.org -> Error
